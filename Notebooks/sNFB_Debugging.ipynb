# %% [markdown]
# #### Template notebook, duplicate this file and rename according to the measurement period

# %% [markdown]
# # Load modules

# %%
import importlib
import simpleNFB.SXM_browser as sxmBrowser
import simpleNFB.DAT_browser as datBrowser
import simpleNFB.base_browser as baseBrowser
importlib.reload(baseBrowser)
importlib.reload(sxmBrowser)
importlib.reload(datBrowser)
import simpleNFB.snfb as snfb
importlib.reload(snfb)

import numpy as np
import matplotlib.pyplot as plt

from IPython import display
from IPython.display import HTML

### enables the notebook to use the full width of the browser window
display.display(HTML("<style>.container { width:100% !important; }</style>"))

### enables asynchronous events and allows the dat browser to handle multiple file selections
# %gui asyncio
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# simple way to set the root directory for both file browsers
shared_root_directory = r'K:\Arc205\THz-STM\amsp\726a_diphenylphenaZnPor_H3_02'

# %% [markdown]
# # Browser .SXM Files

# %%
importlib.reload(sxmBrowser)
# closes previous imageBrowser figure if it exists
figs = list(plt.get_figlabels())
if 'sxm' in figs: plt.close('sxm')
imageBrowser = sxmBrowser.fileBrowser(cmap='Grays_r')
#imageBrowser.rootFolder.value = r'C:\Users\amsp\OneDrive - empa.ch\INT Lab 205 - Documents\📝 Research Output\publications\2025\2025_Ammerman_PorphyrinSTML'
imageBrowser.rootFolder.value = shared_root_directory
imageBrowser.labelToggle.value = True
imageBrowser.depthSelection.value = 3
imageBrowser.nameToggle.value = False
imageBrowser.channelToggle.value = False
imageBrowser.directionToggle.value = False
imageBrowser.labelFontSize.value = 12
# Out:
# Box(children=(Box(children=(Label(value='Session', layout=Layout(flex='0 0 auto', width='10%')), Text(value=''…

# %% [markdown]
# # Browse .Dat Files

# %%
importlib.reload(datBrowser)
# closes previous specBrowser figure if it exists
figs = list(plt.get_figlabels())
if 'dat' in figs: plt.close('dat')
specBrowser = datBrowser.fileBrowser(sxmBrowser=imageBrowser,cmap='G10')
specBrowser.rootFolder.value = shared_root_directory
# Out:
# Box(children=(Box(children=(Label(value='Session', layout=Layout(flex='0 0 auto', width='5%')), Text(value='',…

# %% [markdown]
# ### How to access data from the browsers

# %%
### example of how to set the selection list to a specific file (or list of files)
# generate list of files or save a file selection to a variable
files = specBrowser.selectionList.value
# simple set the selection list value to the list of files [file] or [file1, file2, ...]
specBrowser.selectionList.value = files

# %%
# plot traces can be accessed via specBrowser.figure.data 
## the data is stored as a list of dictionaries, where each dictionary corresponds to a trace.
## the x and y data for each trace can be accessed using the 'x' and 'y' keys of the dictionary (as well as color and other properties)
## a wrapper for this is provided in the form, "get_plot_data()"
# DAT browser — 1D mode
data = specBrowser.get_plot_data()

# x and y are lists of ndarrays, one entry per visible trace

# DAT browser — 2D mode
data_array = specBrowser.get_plot_data()
# ndarray of shape (n_spectra, n_points) — the heatmap z-matrix

# SXM browser
data_array = imageBrowser.get_plot_data()
# ndarray with the dimensions of the displayed (processed) image

# DAT browser file selection is easily accessible with the following:
files = specBrowser.get_file_selection(filter=True) # if the group average filter is enabled the filter=True keyword will return the filtered list of files, otherwise it will return the full list of files

# DAT browser has some spmpy functions wrapped for easy access to the data, such as:
# get channel and get parameter
files = specBrowser.get_file_selection(filter=True)
currents = [np.average(abs(I[0])) for I in specBrowser.get_channel('I',filter=True)]

# %% [markdown]
# # Preview all colormaps

# %%
import plotly.express as px

px.colors.sequential.swatches()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
px.colors.qualitative.swatches()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File c:\Users\amsp\AppData\Local\miniconda3\envs\jup_py3.13\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...
